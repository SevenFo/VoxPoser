# %%
# %cd src
# Out:
# /voxdata/workspace/VoxPoser/src

# %%
from envs.pyrep_quad_env import VoxPoserPyRepQuadcopterEnv
coppelia_scene_path = "/voxdata/workspace/quadcopter.ttt"
env = VoxPoserPyRepQuadcopterEnv(coppelia_scene_path, headless=True)
obs = env.reset()
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# Using GPU
# Using GPU
# QStandardPaths: XDG_RUNTIME_DIR points to non-existing path '/run/user/1000/', please create it with 0700 permissions.
# Camera parameters: {'cam_NE': {'extrinsic_params': array([[ 7.07106709e-01,  0.00000000e+00, -7.07106888e-01,
#          4.80000019e+00],
#        [-7.07106888e-01, -1.19209290e-07, -7.07106829e-01,
#          4.80000019e+00],
#        [ 0.00000000e+00,  1.00000012e+00, -1.19209290e-07,
#          1.50000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00]]), 'intrinsic_params': array([[-659.3946015,    0.       ,  240.       ],
#        [   0.       , -659.3946015,  240.       ],
#        [   0.       ,    0.       ,    1.       ]]), 'far_near': (20.0, 0.009999999776482582)}, 'cam_NW': {'extrinsic_params': array([[ 7.07106709e-01,  0.00000000e+00,  7.07106888e-01,
#         -4.80000019e+00],
#        [ 7.07106888e-01, -1.19209290e-07, -7.07106829e-01,
#          4.80000019e+00],
#        [ 0.00000000e+00,  1.00000012e+00, -1.19209290e-07,
#          1.50000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00]]), 'intrinsic_params': array([[-659.3946015,    0.       ,  240.       ],
#        [   0.       , -659.3946015,  240.       ],
#        [   0.       ,    0.       ,    1.       ]]), 'far_near': (25.0, 0.009999999776482582)}, 'cam_SE': {'extrinsic_params': array([[-7.07106948e-01,  0.00000000e+00, -7.07106829e-01,
#          4.80000019e+00],
#        [-7.07106829e-01, -1.19209290e-07,  7.07106829e-01,
#         -4.80000019e+00],
#        [ 0.00000000e+00,  1.00000012e+00, -1.19209290e-07,
#          1.50000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00]]), 'intrinsic_params': array([[-659.3946015,    0.       ,  240.       ],
#        [   0.       , -659.3946015,  240.       ],
#        [   0.       ,    0.       ,    1.       ]]), 'far_near': (25.0, 0.009999999776482582)}, 'cam_SW': {'extrinsic_params': array([[-7.07107186e-01,  0.00000000e+00,  7.07106709e-01,
#         -4.80000019e+00],
#        [ 7.07106709e-01, -1.19209290e-07,  7.07107067e-01,
#         -4.80000019e+00],
#        [ 0.00000000e+00,  1.00000012e+00, -1.19209290e-07,
#          1.50000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00]]), 'intrinsic_params': array([[-659.3946015,    0.       ,  240.       ],
#        [   0.       , -659.3946015,  240.       ],
#        [   0.       ,    0.       ,    1.       ]]), 'far_near': (25.0, 0.009999999776482582)}, 'Quadricopter_cam': {'extrinsic_params': array([[ 5.96046448e-08,  6.01815104e-01,  7.98635483e-01,
#          0.00000000e+00],
#        [ 1.00000000e+00,  5.96046448e-08, -1.49011612e-07,
#          0.00000000e+00],
#        [-1.49011612e-07,  7.98635483e-01, -6.01815104e-01,
#          2.50000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00]]), 'intrinsic_params': array([[-415.69217983,    0.        ,  240.        ],
#        [   0.        , -415.69217983,  240.        ],
#        [   0.        ,    0.        ,    1.        ]]), 'far_near': (10.0, 0.10000000149011612)}}
# we only process these objects: ['object_']

# %%
env.apply_action([3.0,-2.0,1.8,0,0,0,0,0,0,0])
# Out:
# set target position:  [ 0.16666667 -0.11111111  2.46111111]
# go to next step remainded
# set target position:  [ 0.33333333 -0.22222222  2.42222222]
# go to next step remainded
# set target position:  [ 0.5        -0.33333333  2.38333333]
# go to next step remainded
# set target position:  [ 0.66666667 -0.44444444  2.34444444]
# go to next step remainded
# set target position:  [ 0.83333333 -0.55555556  2.30555556]
# go to next step remainded
# set target position:  [ 1.         -0.66666667  2.26666667]
# go to next step remainded
# set target position:  [ 1.16666667 -0.77777778  2.22777778]
# go to next step remainded
# set target position:  [ 1.33333333 -0.88888889  2.18888889]
# go to next step remainded
# set target position:  [ 1.5  -1.    2.15]
# go to next step remainded
# set target position:  [ 1.66666667 -1.11111111  2.11111111]
# go to next step remainded
# set target position:  [ 1.83333333 -1.22222222  2.07222222]
# go to next step remainded
# set target position:  [ 2.         -1.33333333  2.03333333]
# go to next step remainded
# set target position:  [ 2.16666667 -1.44444444  1.99444444]
# go to next step remainded
# set target position:  [ 2.33333333 -1.55555556  1.95555556]
# go to next step remainded
# set target position:  [ 2.5        -1.66666667  1.91666667]
# go to next step remainded
# set target position:  [ 2.66666667 -1.77777778  1.87777778]
# go to next step remainded
# set target position:  [ 2.83333333 -1.88888889  1.83888889]
# go to next step remainded
# set target position:  [3.0, -2.0, 1.8]
# action is finished
# ({'cam_NE_rgb': array([[[  0, 102, 102],
#           [  0, 102, 102],
#           [  0, 102, 102],
#           ...,
#           [  0, 102, 102],
#           [  0, 102, 102],
#           [  0, 102, 102]],
#
#          [[  0, 102, 102],
#           [  0, 102, 102],
#           [  0, 102, 102],
#           ...,
#           [  0, 102, 102],
#           [  0, 102, 102],
#           [  0, 102, 102]],
#
#          [[  0, 102, 102],
#           [  0, 102, 102],
#           [  0, 102, 102],
#           ...,
#           [  0, 102, 102],
#           [  0, 102, 102],
#           [  0, 102, 102]],
#
#          ...,
#
#          [[210, 205, 196],
#           [211, 206, 203],
#           [212, 207, 198],
#           ...,
#           [209, 204, 192],
#           [206, 201, 191],
#           [209, 201, 193]],
#
#          [[213, 205, 195],
#           [208, 204, 198],
#           [208, 203, 193],
#           ...,
#           [208, 203, 191],
#           [208, 204, 186],
#           [207, 204, 193]],
#
#          [[212, 206, 196],
#           [212, 205, 190],
#           [210, 203, 193],
#           ...,
#           [209, 205, 195],
#           [206, 202, 197],
#           [206, 203, 188]]], dtype=uint8),
#   'cam_NE_depth': array([[0.2063785 , 0.2063785 , 0.2063785 , ..., 0.20637344, 0.20637344,
#           0.20637344],
#          [0.20724863, 0.20724863, 0.20724863, ..., 0.2072435 , 0.2072435 ,
#           0.2072435 ],
#          [0.20812091, 0.20812091, 0.20812091, ..., 0.20811574, 0.20811574,
#           0.20811574],
#          ...,
#          [0.20784141, 0.20784141, 0.20784141, ..., 0.20783624, 0.20784141,
#           0.20784141],
#          [0.20696631, 0.20696631, 0.20696631, ..., 0.20696118, 0.20696631,
#           0.20696631],
#          [0.20609856, 0.20609856, 0.20609856, ..., 0.20609856, 0.20609856,
#           0.20609856]], dtype=float32),
#   'cam_NE_pcd': None,
#   'cam_NW_rgb': array([[[  0, 102, 102],
#           [  0, 102, 102],
#           [  0, 102, 102],
#           ...,
#           [  0, 102, 102],
#           [  0, 102, 102],
#           [  0, 102, 102]],
#
#          [[  0, 102, 102],
#           [  0, 102, 102],
#           [  0, 102, 102],
#           ...,
#           [  0, 102, 102],
#           [  0, 102, 102],
#           [  0, 102, 102]],
#
#          [[  0, 102, 102],
#           [  0, 102, 102],
#           [  0, 102, 102],
#           ...,
#           [  0, 102, 102],
#           [  0, 102, 102],
#           [  0, 102, 102]],
#
#          ...,
#
#          [[219, 213, 198],
#           [227, 220, 214],
#           [229, 223, 216],
#           ...,
#           [224, 218, 203],
#           [223, 217, 207],
#           [224, 218, 209]],
#
#          [[227, 220, 211],
#           [227, 222, 209],
#           [228, 220, 214],
#           ...,
#           [222, 211, 195],
#           [222, 217, 208],
#           [224, 217, 205]],
#
#          [[227, 221, 211],
#           [228, 220, 211],
#           [228, 221, 211],
#           ...,
#           [225, 217, 204],
#           [222, 217, 195],
#           [224, 218, 205]]], dtype=uint8),
#   'cam_NW_depth': array([[0.1650779 , 0.1650779 , 0.1650779 , ..., 0.1650779 , 0.1650779 ,
#           0.16508198],
#          [0.16576982, 0.16576982, 0.16577394, ..., 0.16577394, 0.16577394,
#           0.16577394],
#          [0.16647169, 0.16647169, 0.16647169, ..., 0.16647583, 0.16647583,
#           0.16647583],
#          ...,
#          [0.16625223, 0.16625223, 0.16625223, ..., 0.16624808, 0.16624808,
#           0.16624808],
#          [0.16555221, 0.16555221, 0.16555221, ..., 0.16554812, 0.16554812,
#           0.16554812],
#          [0.16485803, 0.16485803, 0.16485803, ..., 0.16485803, 0.16485803,
#           0.16485803]], dtype=float32),
#   'cam_NW_pcd': None,
#   'cam_SE_rgb': array([[[  0, 102, 102],
#           [  0, 102, 102],
#           [  0, 102, 102],
#           ...,
#           [  0, 102, 102],
#           [  0, 102, 102],
#           [  0, 102, 102]],
#
#          [[  0, 102, 102],
#           [  0, 102, 102],
#           [  0, 102, 102],
#           ...,
#           [  0, 102, 102],
#           [  0, 102, 102],
#           [  0, 102, 102]],
#
#          [[  0, 102, 102],
#           [  0, 102, 102],
#           [  0, 102, 102],
#           ...,
#           [  0, 102, 102],
#           [  0, 102, 102],
#           [  0, 102, 102]],
#
#          ...,
#
#          [[226, 220, 210],
#           [227, 222, 210],
#           [229, 222, 209],
#           ...,
#           [227, 225, 218],
#           [229, 224, 215],
#           [229, 225, 215]],
#
#          [[225, 220, 207],
#           [227, 220, 213],
#           [227, 221, 217],
#           ...,
#           [229, 225, 216],
#           [230, 225, 218],
#           [230, 224, 216]],
#
#          [[228, 222, 210],
#           [228, 222, 209],
#           [230, 223, 213],
#           ...,
#           [231, 225, 218],
#           [230, 225, 218],
#           [229, 226, 215]]], dtype=uint8),
#   'cam_SE_depth': array([[0.1650779 , 0.1650779 , 0.1650779 , ..., 0.1650779 , 0.1650779 ,
#           0.1650779 ],
#          [0.16576982, 0.16576982, 0.16576982, ..., 0.16576982, 0.16576982,
#           0.16576982],
#          [0.16647169, 0.16647169, 0.16647169, ..., 0.16647169, 0.16647169,
#           0.16647169],
#          ...,
#          [0.16624808, 0.16624808, 0.16624808, ..., 0.16625223, 0.16625223,
#           0.16625223],
#          [0.16555221, 0.16555221, 0.16555221, ..., 0.16555221, 0.16555221,
#           0.16555221],
#          [0.16485803, 0.16485803, 0.16485803, ..., 0.16485803, 0.16485803,
#           0.16485803]], dtype=float32),
#   'cam_SE_pcd': None,
#   'cam_SW_rgb': array([[[  0, 102, 102],
#           [  0, 102, 102],
#           [  0, 102, 102],
#           ...,
#           [  0, 102, 102],
#           [  0, 102, 102],
#           [  0, 102, 102]],
#
#          [[  0, 102, 102],
#           [  0, 102, 102],
#           [  0, 102, 102],
#           ...,
#           [  0, 102, 102],
#           [  0, 102, 102],
#           [  0, 102, 102]],
#
#          [[  0, 102, 102],
#           [  0, 102, 102],
#           [  0, 102, 102],
#           ...,
#           [  0, 102, 102],
#           [  0, 102, 102],
#           [  0, 102, 102]],
#
#          ...,
#
#          [[211, 205, 199],
#           [210, 205, 194],
#           [211, 203, 197],
#           ...,
#           [211, 206, 197],
#           [211, 205, 192],
#           [211, 205, 190]],
#
#          [[211, 207, 199],
#           [212, 208, 200],
#           [211, 205, 199],
#           ...,
#           [208, 204, 200],
#           [211, 207, 195],
#           [212, 206, 199]],
#
#          [[210, 205, 198],
#           [210, 206, 196],
#           [211, 204, 195],
#           ...,
#           [210, 205, 197],
#           [212, 205, 192],
#           [212, 206, 199]]], dtype=uint8),
#   'cam_SW_depth': array([[0.1650779 , 0.1650779 , 0.1650779 , ..., 0.1650779 , 0.1650779 ,
#           0.1650779 ],
#          [0.16576982, 0.16576982, 0.16576982, ..., 0.16577394, 0.16577394,
#           0.16577394],
#          [0.16647169, 0.16647169, 0.16647169, ..., 0.16647169, 0.16647169,
#           0.16647169],
#          ...,
#          [0.16624808, 0.16624808, 0.16624808, ..., 0.16624808, 0.16624808,
#           0.16624808],
#          [0.16555221, 0.16555221, 0.16555221, ..., 0.16555221, 0.16555221,
#           0.16555221],
#          [0.16485803, 0.16485803, 0.16485803, ..., 0.16485803, 0.16485803,
#           0.16485803]], dtype=float32),
#   'cam_SW_pcd': None,
#   'Quadricopter_cam_rgb': array([[[ 94, 104, 104],
#           [ 94, 104, 104],
#           [ 94, 104, 104],
#           ...,
#           [ 94, 104, 104],
#           [ 94, 104, 104],
#           [ 94, 104, 104]],
#
#          [[ 94, 104, 104],
#           [ 94, 104, 104],
#           [ 94, 104, 104],
#           ...,
#           [ 94, 104, 104],
#           [ 94, 104, 104],
#           [ 94, 104, 104]],
#
#          [[ 94, 104, 104],
#           [ 94, 104, 104],
#           [ 94, 104, 104],
#           ...,
#           [ 94, 104, 104],
#           [ 94, 104, 104],
#           [ 94, 104, 104]],
#
#          ...,
#
#          [[227, 219, 206],
#           [225, 221, 212],
#           [227, 219, 209],
#           ...,
#           [207, 201, 194],
#           [205, 202, 193],
#           [203, 199, 191]],
#
#          [[224, 221, 208],
#           [227, 221, 209],
#           [228, 219, 211],
#           ...,
#           [205, 200, 193],
#           [208, 203, 190],
#           [204, 199, 188]],
#
#          [[224, 221, 204],
#           [227, 220, 205],
#           [226, 219, 205],
#           ...,
#           [205, 199, 191],
#           [206, 204, 196],
#           [211, 203, 195]]], dtype=uint8),
#   'Quadricopter_cam_depth': array([[0.1571695 , 0.15719795, 0.15722625, ..., 0.17190748, 0.17194116,
#           0.17197464],
#          [0.1573485 , 0.15737702, 0.15740554, ..., 0.17211965, 0.1721534 ,
#           0.17218697],
#          [0.15752791, 0.15755647, 0.15758489, ..., 0.1723321 , 0.17236593,
#           0.1723996 ],
#          ...,
#          [0.16796634, 0.16798894, 0.16801134, ..., 0.17939381, 0.17941917,
#           0.17944479],
#          [0.16762006, 0.16764258, 0.16766492, ..., 0.17900151, 0.1790268 ,
#           0.1790523 ],
#          [0.16727494, 0.16729738, 0.16731963, ..., 0.17861083, 0.178636  ,
#           0.1786614 ]], dtype=float32),
#   'Quadricopter_cam_pcd': None,
#   'quad_pose': array([ 3.01662779, -1.97958779,  1.84180951, -0.02925146, -0.04218589,
#          -0.04111395,  0.99783486, -0.06209287, -0.08187527, -0.08490391])},
#  None,
#  None)

# %%
import matplotlib.pyplot as plt
env.latest_obs = env.get_obs()
# print(env.latest_obs.cam_SE_rgb.shape)
plt.imshow(env.latest_obs.cam_NE_rgb)
plt.show()
plt.imshow(env.latest_obs.cam_SE_rgb)
plt.show()
plt.imshow(env.latest_obs.cam_NW_rgb)
plt.show()
plt.imshow(env.latest_obs.cam_SW_rgb)
plt.show()
plt.imshow(env.latest_obs.Quadricopter_cam_rgb)

# %%
env._pyrep.stop()
env._pyrep.shutdown()
# Out:
# ---------------------------------------------------------------------------
# PyRepError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 env._pyrep.stop()
#       2 env._pyrep.shutdown()
#
# File /usr/local/lib/python3.9/dist-packages/pyrep/pyrep.py:183, in PyRep.stop(self)
#     180 """Stops the physics simulation if it is running.
#     181 """
#     182 if self._ui_thread is None:
# --> 183     raise PyRepError(
#     184         'CoppeliaSim has not been launched. Call launch first.')
#     185 if self.running:
#     186     sim.simStopSimulation()
#
# PyRepError: CoppeliaSim has not been launched. Call launch first.
